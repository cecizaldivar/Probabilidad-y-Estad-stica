# %% [markdown]
# ## Tarea Base de datos
# ### Mariana Urbina
# ### Cecilia Zaldívar
# 9 DE OCTUBRE 2022

# %%
import pandas as pd

# %%
data = pd.read_csv('top50.csv', encoding='ISO-8859-1')
data
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# 13          14                                 Otro Trago - Remix
# 14          15           Money In The Grave (Drake ft. Rick Ross)
# 15          16                          No Guidance (feat. Drake)
# 16          17                                         LA CANCIÓN
# 17          18      Sunflower - Spider-Man: Into the Spider-Verse
# 18          19                                             Lalala
# 19          20                                        Truth Hurts
# 20          21                                Piece Of Your Heart
# 21          22                                             Panini
# 22          23                               No Me Conoce - Remix
# 23          24                                    Soltera - Remix
# 24          25                       bad guy (with Justin Bieber)
# 25          26                                If I Can't Have You
# 26          27                                       Dance Monkey
# 27          28                                           It's You
# 28          29                                          Con Calma
# 29          30                                      QUE PRETENDES
# 30          31                                           Takeaway
# 31          32                                            7 rings
# 32          33                                  0.958333333333333
# 33          34          The London (feat. J. Cole & Travis Scott)
# 34          35                                  Never Really Over
# 35          36  Summer Days (feat. Macklemore & Patrick Stump ...
# 36          37                                         Otro Trago
# 37          38                     Antisocial (with Travis Scott)
# 38          39                                             Sucker
# 39          40  fuck, i'm lonely (with Anne-Marie) - from 13 ...
# 40          41                                        Higher Love
# 41          42                              You Need To Calm Down
# 42          43                                            Shallow
# 43          44                                               Talk
# 44          45                                         Con Altura
# 45          46                                    One Thing Right
# 46          47                                          Te Robaré
# 47          48                                            Happier
# 48          49                                      Call You Mine
# 49          50      Cross Me (feat. Chance the Rapper & PnB Rock)
#
#          Artist.Name             Genre  Beats.Per.Minute  Energy  \
# 0       Shawn Mendes      canadian pop               117      55
# 1           Anuel AA    reggaeton flow               105      81
# 2      Ariana Grande         dance pop               190      80
# 3         Ed Sheeran               pop                93      65
# 4        Post Malone           dfw rap               150      65
# 5         Ed Sheeran               pop               102      68
# 6          Lil Tecca        trap music               180      64
# 7          Sam Smith               pop               111      68
# 8          Lil Nas X       country rap               136      62
# 9      Billie Eilish        electropop               135      43
# 10         Bad Bunny         reggaeton               176      62
# 11          DJ Snake         dance pop                96      71
# 12     Lewis Capaldi               pop               110      41
# 13              Sech    panamanian pop               176      79
# 14             Drake  canadian hip hop               101      50
# 15       Chris Brown         dance pop                93      45
# 16          J Balvin             latin               176      65
# 17       Post Malone           dfw rap                90      48
# 18               Y2K  canadian hip hop               130      39
# 19             Lizzo       escape room               158      62
# 20            MEDUZA         pop house               124      74
# 21         Lil Nas X       country rap               154      59
# 22       Jhay Cortez    reggaeton flow                92      79
# 23             Lunay             latin                92      78
# 24     Billie Eilish        electropop               135      45
# 25      Shawn Mendes      canadian pop               124      82
# 26       Tones and I    australian pop                98      59
# 27         Ali Gatie  canadian hip hop                96      46
# 28      Daddy Yankee             latin                94      86
# 29          J Balvin             latin                93      79
# 30  The Chainsmokers               edm                85      51
# 31     Ariana Grande         dance pop               140      32
# 32            Maluma         reggaeton                96      71
# 33        Young Thug       atl hip hop                98      59
# 34        Katy Perry         dance pop               100      88
# 35     Martin Garrix          big room               114      72
# 36              Sech    panamanian pop               176      70
# 37        Ed Sheeran               pop               152      82
# 38    Jonas Brothers          boy band               138      73
# 39              Lauv         dance pop                95      56
# 40              Kygo               edm               104      68
# 41      Taylor Swift         dance pop                85      68
# 42         Lady Gaga         dance pop                96      39
# 43            Khalid               pop               136      40
# 44           ROSALÍA    r&b en espanol                98      69
# 45        Marshmello           brostep                88      62
# 46         Nicky Jam             latin               176      75
# 47        Marshmello           brostep               100      79
# 48  The Chainsmokers               edm               104      70
# 49        Ed Sheeran               pop                95      79
#
#     Danceability  Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  \
# 0             76              -6         8        75      191               4
# 1             79              -4         8        61      302               8
# 2             40              -4        16        70      186              12
# 3             64              -8         8        55      198              12
# 4             58              -4        11        18      175              45
# 5             80              -5         9        84      220               9
# 6             75              -6         7        23      131               2
# 7             48              -5         8        35      202              15
# 8             88              -6        11        64      157               5
# 9             70             -11        10        56      194              33
# 10            61              -5        24        24      251              60
# 11            82              -4        15        38      185              28
# 12            50              -6        11        45      182              75
# 13            73              -2         6        76      288               7
# 14            83              -4        12        10      205              10
# 15            70              -7        16        14      261              12
# 16            75              -6        11        43      243              15
# 17            76              -6         7        91      158              56
# 18            84              -8        14        50      161              18
# 19            72              -3        12        41      173              11
# 20            68              -7         7        63      153               4
# 21            70              -6        12        48      115              34
# 22            81              -4         9        58      309              14
# 23            80              -4        44        80      266              36
# 24            67             -11        12        68      195              25
# 25            69              -4        13        87      191              49
# 26            82              -6        18        54      210              69
# 27            73              -7        19        40      213              37
# 28            74              -3         6        66      193              11
# 29            64              -4        36        94      222               3
# 30            29              -8        10        36      210              12
# 31            78             -11         9        33      179              59
# 32            78              -5         9        68      176              22
# 33            80              -7        13        18      200               2
# 34            77              -5        32        39      224              19
# 35            66              -7        14        32      164              18
# 36            75              -5        11        62      226              14
# 37            72              -5        36        91      162              13
# 38            84              -5        11        95      181               4
# 39            81              -6         6        68      199              48
# 40            69              -7        10        40      228               2
# 41            77              -6         7        73      171               1
# 42            57              -6        23        32      216              37
# 43            90              -9         6        35      198               5
# 44            88              -4         5        75      162              39
# 45            66              -2        58        44      182               7
# 46            67              -4         8        80      202              24
# 47            69              -3        17        67      214              19
# 48            59              -6        41        50      218              23
# 49            75              -6         7        61      206              21
#
#     Speechiness.  Popularity
# 0              3          79
# 1              9          92
# 2             46          85
# 3             19          86
# 4              7          94
# 5              4          84
# 6             29          92
# 7              9          90
# 8             10          87
# 9             38          95
# 10            31          93
# 11             7          86
# 12             3          88
# 13            20          87
# 14             5          92
# 15            15          82
# 16            32          90
# 17             5          91
# 18             8          88
# 19            11          91
# 20             3          91
# 21             8          91
# 22             7          83
# 23             4          91
# 24            30          89
# 25             6          70
# 26            10          83
# 27             3          89
# 28             6          91
# 29            25          89
# 30             4          84
# 31            33          89
# 32            28          89
# 33            15          89
# 34             6          89
# 35             6          89
# 36            34          91
# 37             5          87
# 38             6          80
# 39             7          78
# 40             3          88
# 41             5          90
# 42             3          87
# 43            13          84
# 44            12          88
# 45             5          88
# 46             6          88
# 47             5          88
# 48             3          88
# 49            12          82

# %% [markdown]
# ### Métodos `.head()` y `.tail()`

# %%
# El método .head(n) permite ver los primeros n renglones de la base de datos
data.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 0      191               4             3          79
# 1      302               8             9          92
# 2      186              12            46          85
# 3      198              12            19          86
# 4      175              45             7          94

# %%
# El método .tail (n) permite ver los últimos n renglones de la base de datos
data.tail(10)
# Out:
#     Unnamed: 0                                     Track.Name  \
# 40          41                                    Higher Love
# 41          42                          You Need To Calm Down
# 42          43                                        Shallow
# 43          44                                           Talk
# 44          45                                     Con Altura
# 45          46                                One Thing Right
# 46          47                                      Te Robaré
# 47          48                                        Happier
# 48          49                                  Call You Mine
# 49          50  Cross Me (feat. Chance the Rapper & PnB Rock)
#
#          Artist.Name           Genre  Beats.Per.Minute  Energy  Danceability  \
# 40              Kygo             edm               104      68            69
# 41      Taylor Swift       dance pop                85      68            77
# 42         Lady Gaga       dance pop                96      39            57
# 43            Khalid             pop               136      40            90
# 44           ROSALÍA  r&b en espanol                98      69            88
# 45        Marshmello         brostep                88      62            66
# 46         Nicky Jam           latin               176      75            67
# 47        Marshmello         brostep               100      79            69
# 48  The Chainsmokers             edm               104      70            59
# 49        Ed Sheeran             pop                95      79            75
#
#     Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 40              -7        10        40      228               2             3
# 41              -6         7        73      171               1             5
# 42              -6        23        32      216              37             3
# 43              -9         6        35      198               5            13
# 44              -4         5        75      162              39            12
# 45              -2        58        44      182               7             5
# 46              -4         8        80      202              24             6
# 47              -3        17        67      214              19             5
# 48              -6        41        50      218              23             3
# 49              -6         7        61      206              21            12
#
#     Popularity
# 40          88
# 41          90
# 42          87
# 43          84
# 44          88
# 45          88
# 46          88
# 47          88
# 48          88
# 49          82

# %% [markdown]
# ## El método `.info()`

# %%
#permite obtener la información básica de nuestra base de datos. Como el número de columnas, los tipos de datos que hay, 
# o si hay datos nulos
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %% [markdown]
# ## El método `.shape`

# %%
#Arroja el tamaño de la base de datos vista como matriz.
data.shape
# Out:
# (50, 14)

# %% [markdown]
# ## El método `.describe()`

# %%
#Arroja un resumen estadístico-descriptivo de los atributos numéricos, con medidas como promedio, media, percentiles y minimos y maximos
data.describe()
# Out:
#        Unnamed: 0  Beats.Per.Minute     Energy  Danceability  Loudness..dB..  \
# count    50.00000         50.000000  50.000000      50.00000       50.000000
# mean     25.50000        120.060000  64.060000      71.38000       -5.660000
# std      14.57738         30.898392  14.231913      11.92988        2.056448
# min       1.00000         85.000000  32.000000      29.00000      -11.000000
# 25%      13.25000         96.000000  55.250000      67.00000       -6.750000
# 50%      25.50000        104.500000  66.500000      73.50000       -6.000000
# 75%      37.75000        137.500000  74.750000      79.75000       -4.000000
# max      50.00000        190.000000  88.000000      90.00000       -2.000000
#
#         Liveness   Valence.     Length.  Acousticness..  Speechiness.  \
# count  50.000000  50.000000   50.000000       50.000000     50.000000
# mean   14.660000  54.600000  200.960000       22.160000     12.480000
# std    11.118306  22.336024   39.143879       18.995553     11.161596
# min     5.000000  10.000000  115.000000        1.000000      3.000000
# 25%     8.000000  38.250000  176.750000        8.250000      5.000000
# 50%    11.000000  55.500000  198.000000       15.000000      7.000000
# 75%    15.750000  69.500000  217.500000       33.750000     15.000000
# max    58.000000  95.000000  309.000000       75.000000     46.000000
#
#        Popularity
# count   50.000000
# mean    87.500000
# std      4.491489
# min     70.000000
# 25%     86.000000
# 50%     88.000000
# 75%     90.750000
# max     95.000000

# %% [markdown]
# # Selección de datos

# %%
#nos da el índice con los nombres de las columnas
data.columns
# Out:
# Index(['Unnamed: 0', 'Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute',
#        'Energy', 'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.',
#        'Length.', 'Acousticness..', 'Speechiness.', 'Popularity'],
#       dtype='object')

# %%
# nos va a dar para cada renglón el atributo de la columna en específico
data["Genre"]
# Out:
# 0         canadian pop
# 1       reggaeton flow
# 2            dance pop
# 3                  pop
# 4              dfw rap
# 5                  pop
# 6           trap music
# 7                  pop
# 8          country rap
# 9           electropop
# 10           reggaeton
# 11           dance pop
# 12                 pop
# 13      panamanian pop
# 14    canadian hip hop
# 15           dance pop
# 16               latin
# 17             dfw rap
# 18    canadian hip hop
# 19         escape room
# 20           pop house
# 21         country rap
# 22      reggaeton flow
# 23               latin
# 24          electropop
# 25        canadian pop
# 26      australian pop
# 27    canadian hip hop
# 28               latin
# 29               latin
# 30                 edm
# 31           dance pop
# 32           reggaeton
# 33         atl hip hop
# 34           dance pop
# 35            big room
# 36      panamanian pop
# 37                 pop
# 38            boy band
# 39           dance pop
# 40                 edm
# 41           dance pop
# 42           dance pop
# 43                 pop
# 44      r&b en espanol
# 45             brostep
# 46               latin
# 47             brostep
# 48                 edm
# 49                 pop
# Name: Genre, dtype: object

# %%
type(data["Genre"])
#nos dice que es una serie
# Out:
# pandas.core.series.Series

# %%
data[["Genre"]]
#asi lo pasamos de serie a data frame
# Out:
#                Genre
# 0       canadian pop
# 1     reggaeton flow
# 2          dance pop
# 3                pop
# 4            dfw rap
# 5                pop
# 6         trap music
# 7                pop
# 8        country rap
# 9         electropop
# 10         reggaeton
# 11         dance pop
# 12               pop
# 13    panamanian pop
# 14  canadian hip hop
# 15         dance pop
# 16             latin
# 17           dfw rap
# 18  canadian hip hop
# 19       escape room
# 20         pop house
# 21       country rap
# 22    reggaeton flow
# 23             latin
# 24        electropop
# 25      canadian pop
# 26    australian pop
# 27  canadian hip hop
# 28             latin
# 29             latin
# 30               edm
# 31         dance pop
# 32         reggaeton
# 33       atl hip hop
# 34         dance pop
# 35          big room
# 36    panamanian pop
# 37               pop
# 38          boy band
# 39         dance pop
# 40               edm
# 41         dance pop
# 42         dance pop
# 43               pop
# 44    r&b en espanol
# 45           brostep
# 46             latin
# 47           brostep
# 48               edm
# 49               pop

# %%
#data frame con columnas que seleccionamos
data[["Track.Name", "Artist.Name", "Genre", "Beats.Per.Minute", "Energy", "Danceability"]]
# Out:
#                                            Track.Name       Artist.Name  \
# 0                                            Señorita      Shawn Mendes
# 1                                               China          Anuel AA
# 2                       boyfriend (with Social House)     Ariana Grande
# 3                     Beautiful People (feat. Khalid)        Ed Sheeran
# 4                         Goodbyes (Feat. Young Thug)       Post Malone
# 5                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 6                                              Ransom         Lil Tecca
# 7                                   How Do You Sleep?         Sam Smith
# 8                               Old Town Road - Remix         Lil Nas X
# 9                                             bad guy     Billie Eilish
# 10                                           Callaita         Bad Bunny
# 11              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# 12                                  Someone You Loved     Lewis Capaldi
# 13                                 Otro Trago - Remix              Sech
# 14           Money In The Grave (Drake ft. Rick Ross)             Drake
# 15                          No Guidance (feat. Drake)       Chris Brown
# 16                                         LA CANCIÓN          J Balvin
# 17      Sunflower - Spider-Man: Into the Spider-Verse       Post Malone
# 18                                             Lalala               Y2K
# 19                                        Truth Hurts             Lizzo
# 20                                Piece Of Your Heart            MEDUZA
# 21                                             Panini         Lil Nas X
# 22                               No Me Conoce - Remix       Jhay Cortez
# 23                                    Soltera - Remix             Lunay
# 24                       bad guy (with Justin Bieber)     Billie Eilish
# 25                                If I Can't Have You      Shawn Mendes
# 26                                       Dance Monkey       Tones and I
# 27                                           It's You         Ali Gatie
# 28                                          Con Calma      Daddy Yankee
# 29                                      QUE PRETENDES          J Balvin
# 30                                           Takeaway  The Chainsmokers
# 31                                            7 rings     Ariana Grande
# 32                                  0.958333333333333            Maluma
# 33          The London (feat. J. Cole & Travis Scott)        Young Thug
# 34                                  Never Really Over        Katy Perry
# 35  Summer Days (feat. Macklemore & Patrick Stump ...     Martin Garrix
# 36                                         Otro Trago              Sech
# 37                     Antisocial (with Travis Scott)        Ed Sheeran
# 38                                             Sucker    Jonas Brothers
# 39  fuck, i'm lonely (with Anne-Marie) - from 13 ...              Lauv
# 40                                        Higher Love              Kygo
# 41                              You Need To Calm Down      Taylor Swift
# 42                                            Shallow         Lady Gaga
# 43                                               Talk            Khalid
# 44                                         Con Altura           ROSALÍA
# 45                                    One Thing Right        Marshmello
# 46                                          Te Robaré         Nicky Jam
# 47                                            Happier        Marshmello
# 48                                      Call You Mine  The Chainsmokers
# 49      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
#
#                Genre  Beats.Per.Minute  Energy  Danceability
# 0       canadian pop               117      55            76
# 1     reggaeton flow               105      81            79
# 2          dance pop               190      80            40
# 3                pop                93      65            64
# 4            dfw rap               150      65            58
# 5                pop               102      68            80
# 6         trap music               180      64            75
# 7                pop               111      68            48
# 8        country rap               136      62            88
# 9         electropop               135      43            70
# 10         reggaeton               176      62            61
# 11         dance pop                96      71            82
# 12               pop               110      41            50
# 13    panamanian pop               176      79            73
# 14  canadian hip hop               101      50            83
# 15         dance pop                93      45            70
# 16             latin               176      65            75
# 17           dfw rap                90      48            76
# 18  canadian hip hop               130      39            84
# 19       escape room               158      62            72
# 20         pop house               124      74            68
# 21       country rap               154      59            70
# 22    reggaeton flow                92      79            81
# 23             latin                92      78            80
# 24        electropop               135      45            67
# 25      canadian pop               124      82            69
# 26    australian pop                98      59            82
# 27  canadian hip hop                96      46            73
# 28             latin                94      86            74
# 29             latin                93      79            64
# 30               edm                85      51            29
# 31         dance pop               140      32            78
# 32         reggaeton                96      71            78
# 33       atl hip hop                98      59            80
# 34         dance pop               100      88            77
# 35          big room               114      72            66
# 36    panamanian pop               176      70            75
# 37               pop               152      82            72
# 38          boy band               138      73            84
# 39         dance pop                95      56            81
# 40               edm               104      68            69
# 41         dance pop                85      68            77
# 42         dance pop                96      39            57
# 43               pop               136      40            90
# 44    r&b en espanol                98      69            88
# 45           brostep                88      62            66
# 46             latin               176      75            67
# 47           brostep               100      79            69
# 48               edm               104      70            59
# 49               pop                95      79            75

# %% [markdown]
# # Seleción usando renglones: Métodos `.loc` y `.iloc`
# - `.loc` localiza renglones por nombre
# - `.ìloc` localiza renglones por índices.

# %%
data.head(8)
# Out:
#    Unnamed: 0                         Track.Name    Artist.Name  \
# 0           1                           Señorita   Shawn Mendes
# 1           2                              China       Anuel AA
# 2           3      boyfriend (with Social House)  Ariana Grande
# 3           4    Beautiful People (feat. Khalid)     Ed Sheeran
# 4           5        Goodbyes (Feat. Young Thug)    Post Malone
# 5           6  I Don't Care (with Justin Bieber)     Ed Sheeran
# 6           7                             Ransom      Lil Tecca
# 7           8                  How Do You Sleep?      Sam Smith
#
#             Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  \
# 0    canadian pop               117      55            76              -6
# 1  reggaeton flow               105      81            79              -4
# 2       dance pop               190      80            40              -4
# 3             pop                93      65            64              -8
# 4         dfw rap               150      65            58              -4
# 5             pop               102      68            80              -5
# 6      trap music               180      64            75              -6
# 7             pop               111      68            48              -5
#
#    Liveness  Valence.  Length.  Acousticness..  Speechiness.  Popularity
# 0         8        75      191               4             3          79
# 1         8        61      302               8             9          92
# 2        16        70      186              12            46          85
# 3         8        55      198              12            19          86
# 4        11        18      175              45             7          94
# 5         9        84      220               9             4          84
# 6         7        23      131               2            29          92
# 7         8        35      202              15             9          90

# %%
data.loc[5]
#nos da la información completa del renglon 5
# Out:
# Unnamed: 0                                          6
# Track.Name          I Don't Care (with Justin Bieber)
# Artist.Name                                Ed Sheeran
# Genre                                             pop
# Beats.Per.Minute                                  102
# Energy                                             68
# Danceability                                       80
# Loudness..dB..                                     -5
# Liveness                                            9
# Valence.                                           84
# Length.                                           220
# Acousticness..                                      9
# Speechiness.                                        4
# Popularity                                         84
# Name: 5, dtype: object

# %%
#me muestra del renglon 10 al 19 con los atributos de las columnas señaladas
data.iloc[10:20][["Track.Name", "Genre", "Energy"]]
# Out:
#                                        Track.Name             Genre  Energy
# 10                                       Callaita         reggaeton      62
# 11          Loco Contigo (feat. J. Balvin & Tyga)         dance pop      71
# 12                              Someone You Loved               pop      41
# 13                             Otro Trago - Remix    panamanian pop      79
# 14       Money In The Grave (Drake ft. Rick Ross)  canadian hip hop      50
# 15                      No Guidance (feat. Drake)         dance pop      45
# 16                                     LA CANCIÓN             latin      65
# 17  Sunflower - Spider-Man: Into the Spider-Verse           dfw rap      48
# 18                                         Lalala  canadian hip hop      39
# 19                                    Truth Hurts       escape room      62

# %% [markdown]
# ## Selección de datos sujetas a condiciones
# Queremos seleccionar aquellas canciones con beats por minuto mayores a 150

# %%
data["Beats.Per.Minute"] >= 150
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-33429813ac29> in <module>
# ----> 1 data["Beats.Per.Minute"] >= 150
#
# NameError: name 'data' is not defined

# %%
#ponemos en un dataframe los renglones que cumplan la condicion
databeats = data[data["Beats.Per.Minute"] >= 150 ]

databeats

# %%
databeats[["Track.Name", "Artist.Name", "Beats.Per.Minute"]]

# %%
#Queremos extraer lo siguiente:

   # - Cancioness con beats mayores a 100 (inclusive) y menores a 150
   # - Longitud mayor a 120

# %%
data[(data["Beats.Per.Minute"]>=100) & (data["Beats.Per.Minute"]<150) & ((data["Length."]> 120))][["Track.Name", "Artist.Name","Beats.Per.Minute", "Length."]]

# %%
#¿Cuáles canciones entre 120 y 250 segundos de duración tuvieron popularidad baja a pesar de tener niveles de "bailabilidad" máximos?

# %%
(data["Length."]>=120) & (data["Length."]<250) & ((data["Popularity"] < 80))

# %%
data["Danceability"] > data["Danceability"].quantile(0.75)

# %%
#respuesta al planteamiento
data[(data["Length."]>=120) & (data["Length."]<250) & ((data["Popularity"] < 80)) & (data["Danceability"] > data["Danceability"].quantile(0.75))]

# %% [markdown]
# ## El método `.groupby()`
# Agrupamiento de datos

# %%
data.groupby("Artist.Name")[["Popularity"]].mean()
# Out:
#                   Popularity
# Artist.Name
# Ali Gatie              89.00
# Anuel AA               92.00
# Ariana Grande          87.00
# Bad Bunny              93.00
# Billie Eilish          92.00
# Chris Brown            82.00
# DJ Snake               86.00
# Daddy Yankee           91.00
# Drake                  92.00
# Ed Sheeran             84.75
# J Balvin               89.50
# Jhay Cortez            83.00
# Jonas Brothers         80.00
# Katy Perry             89.00
# Khalid                 84.00
# Kygo                   88.00
# Lady Gaga              87.00
# Lauv                   78.00
# Lewis Capaldi          88.00
# Lil Nas X              89.00
# Lil Tecca              92.00
# Lizzo                  91.00
# Lunay                  91.00
# MEDUZA                 91.00
# Maluma                 89.00
# Marshmello             88.00
# Martin Garrix          89.00
# Nicky Jam              88.00
# Post Malone            92.50
# ROSALÍA                88.00
# Sam Smith              90.00
# Sech                   89.00
# Shawn Mendes           74.50
# Taylor Swift           90.00
# The Chainsmokers       86.00
# Tones and I            83.00
# Y2K                    88.00
# Young Thug             89.00

# %% [markdown]
# ## El método `.sort_values`

# %%
data.groupby("Artist.Name")[["Popularity"]].mean().sort_values(['Popularity'], ascending= False).head()
# Out:
#              Popularity
# Artist.Name
# Bad Bunny          93.0
# Post Malone        92.5
# Drake              92.0
# Anuel AA           92.0
# Lil Tecca          92.0

# %%
databeats.groupby("Artist.Name")[["Popularity"]].mean().sort_values(['Popularity'], ascending= False).head()
# Out:
#              Popularity
# Artist.Name
# Post Malone        94.0
# Bad Bunny          93.0
# Lil Tecca          92.0
# Lil Nas X          91.0
# Lizzo              91.0

# %% [markdown]
# # Preprocesamiento de datos

# %%
## Datos perdidos: `.isnull()` 
data.isnull().sum()
# Out:
# Unnamed: 0          0
# Track.Name          0
# Artist.Name         0
# Genre               0
# Beats.Per.Minute    0
# Energy              0
# Danceability        0
# Loudness..dB..      0
# Liveness            0
# Valence.            0
# Length.             0
# Acousticness..      0
# Speechiness.        0
# Popularity          0
# dtype: int64

# %% [markdown]
# En este caso no hay valores nulos, pero si los hubiera y los quisieramos quitar, podemos quitar columnas de una base de datos: método .drop()
# Quedaría así:

# %%
#data1 = data.drop("Length.", axis = 1).head()

# %% [markdown]
# ## Datos NaN: Método `.dropna()`

# %%
#data2 = data1.dropna()
#data2.head()

# %%
#data2.isnull().sum()
#nos daria 0 en todas las columnas ya que quitamos valores nulos

# %% [markdown]
# ## Crear un índice

# %%
# Vamos a crear una definición para clasificar (larga, regular, corta) canciones de acuerdo a su duración

def lengthh(longitud):
    if longitud >= 200:
        return "Larga"
    elif longitud >= 145:
        return "Regular"
    else:
        return "Corta"

# %% [markdown]
# El método `.apply()` es útil cuando se requiere aplicar una función al conjunto de datos.

# %%
# Podemos crear una columna que llamaremos Clasificación

data["Clasificación"] = data["Length."].apply(lengthh)

data[["Track.Name","Popularity", "Artist.Name", "Length.", "Clasificación"]]
# Out:
#                                            Track.Name  Popularity  \
# 0                                            Señorita          79
# 1                                               China          92
# 2                       boyfriend (with Social House)          85
# 3                     Beautiful People (feat. Khalid)          86
# 4                         Goodbyes (Feat. Young Thug)          94
# 5                   I Don't Care (with Justin Bieber)          84
# 6                                              Ransom          92
# 7                                   How Do You Sleep?          90
# 8                               Old Town Road - Remix          87
# 9                                             bad guy          95
# 10                                           Callaita          93
# 11              Loco Contigo (feat. J. Balvin & Tyga)          86
# 12                                  Someone You Loved          88
# 13                                 Otro Trago - Remix          87
# 14           Money In The Grave (Drake ft. Rick Ross)          92
# 15                          No Guidance (feat. Drake)          82
# 16                                         LA CANCIÓN          90
# 17      Sunflower - Spider-Man: Into the Spider-Verse          91
# 18                                             Lalala          88
# 19                                        Truth Hurts          91
# 20                                Piece Of Your Heart          91
# 21                                             Panini          91
# 22                               No Me Conoce - Remix          83
# 23                                    Soltera - Remix          91
# 24                       bad guy (with Justin Bieber)          89
# 25                                If I Can't Have You          70
# 26                                       Dance Monkey          83
# 27                                           It's You          89
# 28                                          Con Calma          91
# 29                                      QUE PRETENDES          89
# 30                                           Takeaway          84
# 31                                            7 rings          89
# 32                                  0.958333333333333          89
# 33          The London (feat. J. Cole & Travis Scott)          89
# 34                                  Never Really Over          89
# 35  Summer Days (feat. Macklemore & Patrick Stump ...          89
# 36                                         Otro Trago          91
# 37                     Antisocial (with Travis Scott)          87
# 38                                             Sucker          80
# 39  fuck, i'm lonely (with Anne-Marie) - from 13 ...          78
# 40                                        Higher Love          88
# 41                              You Need To Calm Down          90
# 42                                            Shallow          87
# 43                                               Talk          84
# 44                                         Con Altura          88
# 45                                    One Thing Right          88
# 46                                          Te Robaré          88
# 47                                            Happier          88
# 48                                      Call You Mine          88
# 49      Cross Me (feat. Chance the Rapper & PnB Rock)          82
#
#          Artist.Name  Length. Clasificación
# 0       Shawn Mendes      191       Regular
# 1           Anuel AA      302         Larga
# 2      Ariana Grande      186       Regular
# 3         Ed Sheeran      198       Regular
# 4        Post Malone      175       Regular
# 5         Ed Sheeran      220         Larga
# 6          Lil Tecca      131         Corta
# 7          Sam Smith      202         Larga
# 8          Lil Nas X      157       Regular
# 9      Billie Eilish      194       Regular
# 10         Bad Bunny      251         Larga
# 11          DJ Snake      185       Regular
# 12     Lewis Capaldi      182       Regular
# 13              Sech      288         Larga
# 14             Drake      205         Larga
# 15       Chris Brown      261         Larga
# 16          J Balvin      243         Larga
# 17       Post Malone      158       Regular
# 18               Y2K      161       Regular
# 19             Lizzo      173       Regular
# 20            MEDUZA      153       Regular
# 21         Lil Nas X      115         Corta
# 22       Jhay Cortez      309         Larga
# 23             Lunay      266         Larga
# 24     Billie Eilish      195       Regular
# 25      Shawn Mendes      191       Regular
# 26       Tones and I      210         Larga
# 27         Ali Gatie      213         Larga
# 28      Daddy Yankee      193       Regular
# 29          J Balvin      222         Larga
# 30  The Chainsmokers      210         Larga
# 31     Ariana Grande      179       Regular
# 32            Maluma      176       Regular
# 33        Young Thug      200         Larga
# 34        Katy Perry      224         Larga
# 35     Martin Garrix      164       Regular
# 36              Sech      226         Larga
# 37        Ed Sheeran      162       Regular
# 38    Jonas Brothers      181       Regular
# 39              Lauv      199       Regular
# 40              Kygo      228         Larga
# 41      Taylor Swift      171       Regular
# 42         Lady Gaga      216         Larga
# 43            Khalid      198       Regular
# 44           ROSALÍA      162       Regular
# 45        Marshmello      182       Regular
# 46         Nicky Jam      202         Larga
# 47        Marshmello      214         Larga
# 48  The Chainsmokers      218         Larga
# 49        Ed Sheeran      206         Larga

# %% [markdown]
# ## Algunos gráficos

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({"font.size":20, "figure.figsize": (12,9)} )

# %%
data.head()

# %%
data.describe()

# %%
#diagrama de dispersión entre dos variables
data.plot(kind = "scatter", x = "Popularity", y = "Danceability", title = "Popularity vs Danceability")

# %%
#histograma de popularidad
data["Popularity"].plot(kind = "hist", title = "Popularity")

# %%
data["Popularity"].plot(kind = "box")

# %%
data.boxplot(column = "Danceability", by = "Popularity")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# Vamos a limpiar Popularidad

# %%
data["Clasifiación"] = data["Popularity"].apply(lengthh)

data.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity Clasificación  \
# 0      191               4             3          79       Regular
# 1      302               8             9          92         Larga
# 2      186              12            46          85       Regular
# 3      198              12            19          86       Regular
# 4      175              45             7          94       Regular
#
#   Clasifiación
# 0        Corta
# 1        Corta
# 2        Corta
# 3        Corta
# 4        Corta

# %%
data.boxplot(column = "Danceability", by = "Clasificación")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# CONCLUSIONES:
# AL REALIZAR EL ANÁLISIS DESCRIPTIVO DE NUESTRA BASE DE DATOS RELACIONADO CON LA MÚSICA NOS DIMOS CUENTA DE QUE ÉSTE NOS PERMITE ABSTRAER LA INFORMACIÓN DE MANERA QUE PUDIMOS COMPRENDERLA DESDE UN NUEVO PUNTO DE VISTA Y ES AHÍ CUANDO VEMOS EL VALOR QUE TIENE EL SABER INTERPRETARLA CORRECTAMENTE.LAS LIBRERÍAS QUE USAMOS (PANDAS Y MATPLOT) TIENEN LAS CARACTERÍSTICAS FUNDAMENTALES PARA PRESENTAR, POR LO MENOS, UN ANÁLISIS INTRODUCTORIO COMPLETO Y CONCISO.
# LAS PRIMERAS FUNCIONES REALIZADAS, COMO SHAPE, INFO Y DESCRIBE A PESAR DE SER MUY BÁSICAS NOS DAN EL PUNTO DE REFERENCIA PARA EMPEZAR CON ANÁLISIS MÁS PROFUNDOS. PARA ELLO UTILIZAMOS AGRUPACIONES Y SELECCIONES PARA PONER CONDICIONES A NUESTROS DATOS, SEGMENTARLOS Y PLANTEAR PREGUNTAS MÁS COMPLICADAS A LAS QUE PUDIMOS ENCONTRAR RESPUESTA GRACIAS A ESTE PROCESO. POR ÚLTIMO, LAS GRÁFICAS ELEGIDAS NOS DAN UNA NUEVA PERSEPCTIVA QUE ES MUY IMPORTANTE YA QUE DE UN VISTAZO PODEMOS VER RELACIONES ENTRE DOS VARIABLES EN EL DIAGRAMA DE DISPERSIÓN, EL COMPORTAMIENTO QUE SIGUEN CIERTAS VARIABLES CON EL HISTOGRAMA Y DETECTAMOS VALORES ATIPICOS CON LA VISUALIZACIÓNDE BOX PLOTS. DE LAS COSAS MÁS UTILES ES EL HECHO DE QUE PUDIMOS CREAR NUESTROS PROPIOS PARÁMETROS PARA AGREGARLOS AL DATAFRAME ORIGINAL Y PODER INCLUIRLOS EN EL ANÁLISIS FINAL
